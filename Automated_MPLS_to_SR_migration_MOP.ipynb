# %% [markdown]
# #  ****Playbook for SR enablement Demo in LDP/IP network **

# %% [markdown]
# ## ****Validation of MPLS**

# %% [markdown]
# #### First we check that all core router interfaces are enabled with MPLS

# %%
# !ansible-playbook roles/Show_commands/tasks/ntc-show-cmd.yml --extra-vars "target=core commands='show mpls interfaces'"

import ast
import pandas as pd
import os
hosts = !ansible core --list-hosts
data = [line.rstrip("\n\r") for line in open("roles/Show_commands/output/show_cmd_ouput_json.txt", "r")]
data = data[0]
data = ast.literal_eval(data)
total_host = len(data)
for x in range(total_host):
    data0 = data[x]
    locals()['df{0}'.format(x)] = pd.DataFrame(data0)
    locals()['df{0}'.format(x)] = locals()['df{0}'.format(x)].set_index("interface")
    locals()['df{0}'.format(x)] = locals()['df{0}'.format(x)].style.set_caption('Host: '+ str(hosts[x+1]))
    display(locals()['df{0}'.format(x)])


# !ansible-playbook roles/Show_commands/tasks/ntc-show-cmd.yml --extra-vars "target=P1 commands='sh mpls forwarding'"


import ast
import pandas as pd


def highlight_cols(s):
    color = 'lightyellow'
    return 'background-color: %s' % color
hosts = !ansible core --list-hosts
data = [line.rstrip("\n\r") for line in open("roles/Show_commands/output/show_cmd_ouput_json.txt", "r")]
data = data[0]
data = ast.literal_eval(data)
total_host = len(data)
for x in range(total_host):
    data0 = data[x]
    locals()['df{0}'.format(x)] = pd.DataFrame(data0)
    locals()['df{0}'.format(x)] = locals()['df{0}'.format(x)][["prefix","local_label","out_label","next_hop","out_intf","bytes_switched"]]
    locals()['df{0}'.format(x)] = locals()['df{0}'.format(x)].style.set_caption('Host: '+ str(hosts[x+1])).applymap(highlight_cols, subset=pd.IndexSlice[:, ['prefix', 'bytes_switched']])
    display(locals()['df{0}'.format(x)])

# !ansible-playbook roles/Show_commands/tasks/ntc-show-cmd.yml --extra-vars "target=P1 commands='sh mpls label table'"

hosts = !ansible core --list-hosts
data = [line.rstrip("\n\r") for line in open("roles/Show_commands/output/show_cmd_ouput_json.txt", "r")]
data = data[0] 
data = ast.literal_eval(data)
total_host = len(data) 
for x in range(total_host):
    data0 = data[x]
    locals()['df{0}'.format(x)] = pd.DataFrame(data0)
    locals()['df{0}'.format(x)] = locals()['df{0}'.format(x)].set_index("label")
    locals()['df{0}'.format(x)] = locals()['df{0}'.format(x)].style.set_caption('Host: '+ str(hosts[x+1]))
    display(locals()['df{0}'.format(x)])

    
    
    
    
print "="*30
print "Done Move to Next step"
print "="*30
# Out:
# PLAY [core] ********************************************************************
#
# TASK [Show command collection for XR] ******************************************
# ok: [P1]
# ok: [P4]
# ok: [P3]
# ok: [P2]
#
# TASK [copy] ********************************************************************
# changed: [P1]
#
# PLAY RECAP *********************************************************************
# P1                         : ok=2    changed=1    unreachable=0    failed=0
# P2                         : ok=1    changed=0    unreachable=0    failed=0
# P3                         : ok=1    changed=0    unreachable=0    failed=0
# P4                         : ok=1    changed=0    unreachable=0    failed=0
# <style  type="text/css" >
# </style>
# <table id="T_0fd324ae_21ac_11e9_9c9b_000c294bdf13" ><caption>Host:     P1</caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >enabled</th>
# ...

# %% [markdown]
# ## ****Configure Segement routing on all Core routers**

# %%
# !ansible-playbook  roles/SR_enable/tasks/SR_enable_XR_routers.yml --extra-vars "target=core"
print "="*30
print "Done Move to Next step"
print "="*30
# Out:
# PLAY [core] ********************************************************************
#
# TASK [Configuring SR global config selected router] ****************************
# changed: [P4]
# changed: [P3]
# changed: [P2]
# changed: [P1]
#
# PLAY RECAP *********************************************************************
# P1                         : ok=1    changed=1    unreachable=0    failed=0
# P2                         : ok=1    changed=1    unreachable=0    failed=0
# P3                         : ok=1    changed=1    unreachable=0    failed=0
# P4                         : ok=1    changed=1    unreachable=0    failed=0
#
# ...
# Done Move to Next step
# ...

# %% [markdown]
# #### Validate correctly SR configured

# %%
# !ansible-playbook roles/Show_commands/tasks/XR-show-cmd.yml --extra-vars "target=core commands=['sh running-config router isis xr address-family ipv4 unicast','sh running-config router isis xr interface loopback 0']"
print "="*30
print "Done Move to Next step"
print "="*30
# Out:
# PLAY [core] ********************************************************************
#
# TASK [Show command collection for XR] ******************************************
# ok: [P2]
# ok: [P3]
# ok: [P1]
# ok: [P4]
#
# TASK [debug] *******************************************************************
# ok: [P1] => {
#     "show_command.stdout_lines": [
#         [
#             "router isis xr",
#             " address-family ipv4 unicast",
#             "  metric-style wide",
#             "  mpls traffic-eng level-1",
#             "  mpls traffic-eng router-id Loopback0",
#             "  mpls traffic-eng multicast-intact",
#             "  segment-routing mpls",
#             " !",
#             "!"
#         ],
#         [
#             "router isis xr",
#             " interface Loopback0",
#             "  address-family ipv4 unicast",
#             "   prefix-sid absolute 16001",
#             "  !",
#             " !",
#             "!"
#         ]
#     ]
# }
# ok: [P2] => {
# ...

# %% [markdown]
# #### Validate that SR labels are allocated

# %%
# !ansible-playbook roles/Show_commands/tasks/ntc-show-cmd.yml --extra-vars "target=P1,P2 commands='sh mpls forwarding'"


import ast
import pandas as pd

def highlight_cols(s):
    color = 'lightyellow'
    return 'background-color: %s' % color
hosts = !ansible P1,P2 --list-hosts
data = [line.rstrip("\n\r") for line in open("roles/Show_commands/output/show_cmd_ouput_json.txt", "r")]
data = data[0]
data = ast.literal_eval(data)
total_host = len(data)
for x in range(total_host):
    data0 = data[x]
    locals()['df{0}'.format(x)] = pd.DataFrame(data0)
    locals()['df{0}'.format(x)] = locals()['df{0}'.format(x)][["prefix","local_label","out_label","next_hop","out_intf","bytes_switched"]]
    locals()['df{0}'.format(x)] = locals()['df{0}'.format(x)].style.set_caption('Host: '+ str(hosts[x+1])).applymap(highlight_cols, subset=pd.IndexSlice[:, ['prefix', 'bytes_switched']])
    display(locals()['df{0}'.format(x)])

# !ansible-playbook roles/Show_commands/tasks/ntc-show-cmd.yml --extra-vars "target=P1,P2 commands='sh mpls label table'"

hosts = !ansible P1,P2 --list-hosts
data = [line.rstrip("\n\r") for line in open("roles/Show_commands/output/show_cmd_ouput_json.txt", "r")]
data = data[0] 
data = ast.literal_eval(data)
total_host = len(data) 
for x in range(total_host):
    data0 = data[x]
    locals()['df{0}'.format(x)] = pd.DataFrame(data0)
    locals()['df{0}'.format(x)] = locals()['df{0}'.format(x)].set_index("label")
    locals()['df{0}'.format(x)] = locals()['df{0}'.format(x)].style.set_caption('Host: '+ str(hosts[x+1]))
    display(locals()['df{0}'.format(x)])

    
# !ansible-playbook roles/Show_commands/tasks/XR-show-cmd.yml --extra-vars "target=P1,P2 commands='sh mpls label table application isis detail'"

print "="*30
print "Done Move to Next step"
print "="*30
# Out:
# PLAY [P1,P2] *******************************************************************
#
# TASK [Show command collection for XR] ******************************************
# ok: [P2]
# ok: [P1]
#
# TASK [copy] ********************************************************************
# changed: [P1]
#
# PLAY RECAP *********************************************************************
# P1                         : ok=2    changed=1    unreachable=0    failed=0
# P2                         : ok=1    changed=0    unreachable=0    failed=0
# <style  type="text/css" >
#     #T_5444086c_21b4_11e9_9c9c_000c294bdf13row0_col0 {
#             background-color:  lightyellow;
#         }    #T_5444086c_21b4_11e9_9c9c_000c294bdf13row0_col5 {
#             background-color:  lightyellow;
#         }    #T_5444086c_21b4_11e9_9c9c_000c294bdf13row1_col0 {
#             background-color:  lightyellow;
#         }    #T_5444086c_21b4_11e9_9c9c_000c294bdf13row1_col5 {
#             background-color:  lightyellow;
# ...

# %% [markdown]
# ## ****Now configure SR Prefer over LDP in core**

# %%
# !ansible-playbook  roles/SR_prefer/tasks/SR-prefer-config.yml --extra-vars "target=core"
print "="*30
print "Done Move to Next step"
print "="*30
# Out:
# PLAY [core] ********************************************************************
#
# TASK [Configuring SR Prefer on selected Router] ********************************
# ok: [P1]
# changed: [P3]
# changed: [P4]
# changed: [P2]
#
# PLAY RECAP *********************************************************************
# P1                         : ok=1    changed=0    unreachable=0    failed=0
# P2                         : ok=1    changed=1    unreachable=0    failed=0
# P3                         : ok=1    changed=1    unreachable=0    failed=0
# P4                         : ok=1    changed=1    unreachable=0    failed=0
#
# ...
# Done Move to Next step
# ...

# %% [markdown]
# #### Validate it's correctly configured

# %%
# !ansible-playbook roles/Show_commands/tasks/XR-show-cmd.yml --extra-vars "target=core commands=['sh running-config router isis xr address-family ipv4 unicast']"

print "="*30
print "Done Move to Next step"
print "="*30
# Out:
# PLAY [core] ********************************************************************
#
# TASK [Show command collection for XR] ******************************************
# ok: [P1]
# ok: [P4]
# ok: [P2]
# ok: [P3]
#
# TASK [debug] *******************************************************************
# ok: [P1] => {
#     "show_command.stdout_lines": [
#         [
#             "router isis xr",
#             " address-family ipv4 unicast",
#             "  metric-style wide",
#             "  mpls traffic-eng level-1",
#             "  mpls traffic-eng router-id Loopback0",
#             "  mpls traffic-eng multicast-intact",
#             "  segment-routing mpls sr-prefer",
#             " !",
#             "!"
#         ]
#     ]
# }
# ok: [P2] => {
#     "show_command.stdout_lines": [
#         [
#             "router isis xr",
#             " address-family ipv4 unicast",
#             "  metric-style wide",
#             "  mpls traffic-eng level-1",
# ...

# %% [markdown]
# #### Validate SR forwarding

# %%
# !ansible-playbook roles/Show_commands/tasks/ntc-show-cmd.yml --extra-vars "target=P1,P2 commands='sh mpls forwarding'"


import ast
import pandas as pd

def highlight_cols(s):
    color = 'lightyellow'
    return 'background-color: %s' % color
hosts = !ansible P1,P2 --list-hosts
data = [line.rstrip("\n\r") for line in open("roles/Show_commands/output/show_cmd_ouput_json.txt", "r")]
data = data[0]
data = ast.literal_eval(data)
total_host = len(data)
for x in range(total_host):
    data0 = data[x]
    locals()['df{0}'.format(x)] = pd.DataFrame(data0)
    locals()['df{0}'.format(x)] = locals()['df{0}'.format(x)][["prefix","local_label","out_label","next_hop","out_intf","bytes_switched"]]
    locals()['df{0}'.format(x)] = locals()['df{0}'.format(x)].style.set_caption('Host: '+ str(hosts[x+1])).applymap(highlight_cols, subset=pd.IndexSlice[:, ['prefix', 'bytes_switched']])
    display(locals()['df{0}'.format(x)])

    
print "="*30
print "Done Move to Next step"
print "="*30
# Out:
# PLAY [P1,P2] *******************************************************************
#
# TASK [Show command collection for XR] ******************************************
# ok: [P2]
# ok: [P1]
#
# TASK [copy] ********************************************************************
# changed: [P1]
#
# PLAY RECAP *********************************************************************
# P1                         : ok=2    changed=1    unreachable=0    failed=0
# P2                         : ok=1    changed=0    unreachable=0    failed=0
# <style  type="text/css" >
#     #T_8a3d5648_21ba_11e9_9c9c_000c294bdf13row0_col0 {
#             background-color:  lightyellow;
#         }    #T_8a3d5648_21ba_11e9_9c9c_000c294bdf13row0_col5 {
#             background-color:  lightyellow;
#         }    #T_8a3d5648_21ba_11e9_9c9c_000c294bdf13row1_col0 {
#             background-color:  lightyellow;
#         }    #T_8a3d5648_21ba_11e9_9c9c_000c294bdf13row1_col5 {
#             background-color:  lightyellow;
# ...

# %% [markdown]
# ## ****NOW we will configure Prefix-SID for Loopback 10 (Which is loopback for Global BGP)**

# %%
# !ansible-playbook roles/Global_internet_SR/tasks/Global_internet_SR_config.yml --extra-vars "target=core"
# !ansible-playbook roles/Show_commands/tasks/XR-show-cmd.yml --extra-vars "target=core commands=['sh running-config router isis xr interface loopback 10']"


print "="*30
print "Done Move to Next step"
print "="*30
# Out:
# PLAY [core] ********************************************************************
#
# TASK [Configuring SR for global internet services] *****************************
# changed: [P2]
# changed: [P1]
# changed: [P4]
# changed: [P3]
#
# PLAY RECAP *********************************************************************
# P1                         : ok=1    changed=1    unreachable=0    failed=0
# P2                         : ok=1    changed=1    unreachable=0    failed=0
# P3                         : ok=1    changed=1    unreachable=0    failed=0
# P4                         : ok=1    changed=1    unreachable=0    failed=0
#
#
# PLAY [core] ********************************************************************
#
# TASK [Show command collection for XR] ******************************************
# ok: [P3]
# ok: [P1]
# ok: [P4]
# ok: [P2]
#
# TASK [debug] *******************************************************************
# ok: [P1] => {
#     "show_command.stdout_lines": [
#         [
# ...

# %% [markdown]
# #### Validate MPLS forwarding

# %%
# !ansible-playbook roles/Show_commands/tasks/ntc-show-cmd.yml --extra-vars "target=P1,P2 commands='sh mpls forwarding'"


import ast
import pandas as pd

def highlight_cols(s):
    color = 'lightyellow'
    return 'background-color: %s' % color
hosts = !ansible P1,P2 --list-hosts
data = [line.rstrip("\n\r") for line in open("roles/Show_commands/output/show_cmd_ouput_json.txt", "r")]
data = data[0]
data = ast.literal_eval(data)
total_host = len(data)
for x in range(total_host):
    data0 = data[x]
    locals()['df{0}'.format(x)] = pd.DataFrame(data0)
    locals()['df{0}'.format(x)] = locals()['df{0}'.format(x)][["prefix","local_label","out_label","next_hop","out_intf","bytes_switched"]]
    locals()['df{0}'.format(x)] = locals()['df{0}'.format(x)].style.set_caption('Host: '+ str(hosts[x+1])).applymap(highlight_cols, subset=pd.IndexSlice[:, ['prefix', 'bytes_switched']])
    display(locals()['df{0}'.format(x)])

print "="*30
print "Done Move to Next step"
print "="*30
# Out:
# PLAY [P1,P2] *******************************************************************
#
# TASK [Show command collection for XR] ******************************************
# ok: [P1]
# ok: [P2]
#
# TASK [copy] ********************************************************************
# changed: [P1]
#
# PLAY RECAP *********************************************************************
# P1                         : ok=2    changed=1    unreachable=0    failed=0
# P2                         : ok=1    changed=0    unreachable=0    failed=0
# <style  type="text/css" >
#     #T_2d283730_21be_11e9_9c9c_000c294bdf13row0_col0 {
#             background-color:  lightyellow;
#         }    #T_2d283730_21be_11e9_9c9c_000c294bdf13row0_col5 {
#             background-color:  lightyellow;
#         }    #T_2d283730_21be_11e9_9c9c_000c294bdf13row1_col0 {
#             background-color:  lightyellow;
#         }    #T_2d283730_21be_11e9_9c9c_000c294bdf13row1_col5 {
#             background-color:  lightyellow;
# ...

# %% [markdown]
# #### Validate GW forwarding for internet traffic subnet

# %%
# !ansible-playbook roles/Show_commands/tasks/XR-show-cmd.yml --extra-vars "target=P1 commands=['sh cef 144.228.242.100/32 detail']"
# !ansible-playbook roles/Show_commands/tasks/XR-show-cmd.yml --extra-vars "target=P1 commands=['sh cef 144.228.242.200/32 detail']"

print "="*30
print "Done Move to Next step"
print "="*30
# Out:
# PLAY [P1] **********************************************************************
#
# TASK [Show command collection for XR] ******************************************
# ok: [P1]
#
# TASK [debug] *******************************************************************
# ok: [P1] => {
#     "show_command.stdout_lines": [
#         [
#             "144.228.242.100/32, version 42, internal 0x1000001 0x0 (ptr 0x821dda28) [3], 0x0 (0x82776db8), 0x0 (0x0)",
#             " Updated Jan 18 18:01:27.742 ",
#             " local adjacency 10.10.0.7",
#             " Prefix Len 32, traffic index 0, precedence n/a, priority 1",
#             "  gateway array (0x8260ad50) reference count 6, flags 0x0, source rib (7), 0 backups",
#             "                [7 type 3 flags 0x8401 (0x826b0178) ext 0x0 (0x0)]",
#             "  LW-LDI[type=3, refc=1, ptr=0x82776db8, sh-ldi=0x826b0178]",
#             "  gateway array update type-time 1 Jan 18 18:01:27.741",
# ...

# %% [markdown]
# #### Validate on P3 that Ipv4 Global Internet traffic is SR switched

# %%
# !ansible-playbook roles/Show_commands/tasks/XR-show-cmd.yml --extra-vars "target=P3 commands=['sh cef 144.228.242.40/32 detail']"


print "="*30
print "Done Move to Next step"
print "="*30
# Out:
# PLAY [P3] **********************************************************************
#
# TASK [Show command collection for XR] ******************************************
# ok: [P3]
#
# TASK [debug] *******************************************************************
# ok: [P3] => {
#     "show_command.stdout_lines": [
#         [
#             "144.228.242.40/32, version 3011, labeled SR, internal 0x1000001 0x83 (ptr 0x821c99d8) [3], 0x0 (0x82776a70), 0xa20 (0x82ab8178)",
#             " Updated Jan 26 22:58:20.222 ",
#             " local adjacency 10.10.0.114",
#             " Prefix Len 32, traffic index 0, precedence n/a, priority 1",
#             " Extensions: context-label:18004",
#             "  gateway array (0x8260dc90) reference count 6, flags 0x68, source rib (7), 0 backups",
#             "                [5 type 4 flags 0x8401 (0x82af8e18) ext 0x0 (0x0)]",
#             "  LW-LDI[type=1, refc=1, ptr=0x82776a70, sh-ldi=0x82af8e18]",
# ...

# %% [markdown]
# ## ****Now configure P1 as Mapping server for prefix-SIDs for all Loopback0(L3vpn) and Loopback10(Global) of the known prefixes.**

# %%
# !ansible-playbook  roles/SR_mapping_server/tasks/SR-mapping-server-config.yml --extra-vars "target=P1"
# !ansible-playbook roles/Show_commands/tasks/XR-show-cmd.yml --extra-vars "target=P1 commands=['sh running-config segment-routing mapping-server','sh running-config router isis xr address-family ipv4 unicast']"


print "="*30
print "Done Move to Next step"
print "="*30
# Out:
# PLAY [P1] **********************************************************************
#
# TASK [Configuring selected Core Router as Mapping Server] **********************
# changed: [P1]
#
# PLAY RECAP *********************************************************************
# P1                         : ok=1    changed=1    unreachable=0    failed=0
#
#
# PLAY [P1] **********************************************************************
#
# TASK [Show command collection for XR] ******************************************
# ok: [P1]
#
# TASK [debug] *******************************************************************
# ok: [P1] => {
#     "show_command.stdout_lines": [
#         [
#             "segment-routing",
#             " mapping-server",
#             "  prefix-sid-map",
#             "   address-family ipv4",
#             "    172.16.0.1/32 400 range 255",
#             "    144.228.242.1/32 1000 range 255",
#             "   !",
#             "  !",
#             " !",
# ...

# %% [markdown]
# #### Validate MPLS forwarding

# %%
print "="*30
print "clearing MPLS forwarding table"
print "="*30


# !ansible-playbook roles/Show_commands/tasks/XR-show-cmd.yml --extra-vars "target=P1,P4 commands=['clear mpls forwarding counters']"

print "="*30
print "MPLS forwarding table"
print "="*30

# !ansible-playbook roles/Show_commands/tasks/ntc-show-cmd.yml --extra-vars "target=P1,P4 commands='sh mpls forwarding'"


import ast
import pandas as pd

def highlight_cols(s):
    color = 'lightyellow'
    return 'background-color: %s' % color
hosts = !ansible P1,P4 --list-hosts
data = [line.rstrip("\n\r") for line in open("roles/Show_commands/output/show_cmd_ouput_json.txt", "r")]
data = data[0]
data = ast.literal_eval(data)
total_host = len(data)
for x in range(total_host):
    data0 = data[x]
    locals()['df{0}'.format(x)] = pd.DataFrame(data0)
    locals()['df{0}'.format(x)] = locals()['df{0}'.format(x)][["prefix","local_label","out_label","next_hop","out_intf","bytes_switched"]]
    locals()['df{0}'.format(x)] = locals()['df{0}'.format(x)].style.set_caption('Host: '+ str(hosts[x+1])).applymap(highlight_cols, subset=pd.IndexSlice[:, ['prefix', 'bytes_switched']])
    display(locals()['df{0}'.format(x)])



# !ansible-playbook roles/Show_commands/tasks/XR-show-cmd.yml --extra-vars "target=P1 commands=['sh cef 144.228.242.100/32 detail']"
# !ansible-playbook roles/Show_commands/tasks/XR-show-cmd.yml --extra-vars "target=P1 commands=['sh cef 144.228.242.200/32 detail']"
# !ansible-playbook roles/Show_commands/tasks/XR-show-cmd.yml --extra-vars "target=P1 commands=['sh cef 172.16.0.33/32 detail']"
# !ansible-playbook roles/Show_commands/tasks/XR-show-cmd.yml --extra-vars "target=P1 commands=['sh cef 172.16.0.44/32 detail']"


# !ansible-playbook roles/Show_commands/tasks/XR-show-cmd.yml --extra-vars "target=P2 commands=['sh cef 144.228.242.200/32 detail']"


print "="*30
print "Done Move to Next step"
print "="*30
# Out:
# ...
# clearing MPLS forwarding table
# ...
#
# PLAY [P1,P4] *******************************************************************
#
# TASK [Show command collection for XR] ******************************************
# ok: [P4]
# ok: [P1]
#
# TASK [debug] *******************************************************************
# ok: [P1] => {
#     "show_command.stdout_lines": [
#         [
#             ""
#         ]
#     ]
# }
# ok: [P4] => {
#     "show_command.stdout_lines": [
#         [
#             ""
#         ]
#     ]
# }
#
# PLAY RECAP *********************************************************************
# P1                         : ok=2    changed=0    unreachable=0    failed=0
# P4                         : ok=2    changed=0    unreachable=0    failed=0
#
# ...
# MPLS forwarding table
# ...
#
# PLAY [P1,P4] *******************************************************************
#
# TASK [Show command collection for XR] ******************************************
# ok: [P4]
# ok: [P1]
#
# ...

# %% [markdown]
# #### Validate MPLS forwarding for Global Ipv4 on P2

# %%
# !ansible-playbook roles/Show_commands/tasks/XR-show-cmd.yml --extra-vars "target=P2 commands=['sh cef 144.228.242.200/32 detail']"

print "="*30
print "Done Move to Next step"
print "="*30
# Out:
# PLAY [P2] **********************************************************************
#
# TASK [Show command collection for XR] ******************************************
# ok: [P2]
#
# TASK [debug] *******************************************************************
# ok: [P2] => {
#     "show_command.stdout_lines": [
#         [
#             "144.228.242.200/32, version 1623, labeled SR, internal 0x1000001 0x83 (ptr 0x821c8b10) [3], 0x0 (0x829cb218), 0xa28 (0x82ab8258)",
#             " Updated Jan 26 23:11:15.737 ",
#             " local adjacency 10.10.0.6",
#             " Prefix Len 32, traffic index 0, precedence n/a, priority 1",
#             " Extensions: context-label:17199",
#             "  gateway array (0x8285f770) reference count 6, flags 0x68, source rib (7), 0 backups",
#             "                [3 type 5 flags 0x8401 (0x82af8e78) ext 0x0 (0x0)]",
#             "  LW-LDI[type=5, refc=3, ptr=0x829cb218, sh-ldi=0x82af8e78]",
# ...

# %% [markdown]
# ##  ****Configure PE3 and PE4 as SR and then prefer SR over LDP**

# %%
print "="*40
print "Pre-check MPLS forwarding before Configuring SR"
print "="*40


# !ansible-playbook roles/Show_commands/tasks/ntc-show-cmd.yml --extra-vars "target=PE3,PE4 commands='sh mpls forwarding'"


import ast
import pandas as pd

def highlight_cols(s):
    color = 'lightyellow'
    return 'background-color: %s' % color
hosts = !ansible PE3,PE4 --list-hosts
data = [line.rstrip("\n\r") for line in open("roles/Show_commands/output/show_cmd_ouput_json.txt", "r")]
data = data[0]
data = ast.literal_eval(data)
total_host = len(data)
for x in range(total_host):
    data0 = data[x]
    locals()['df{0}'.format(x)] = pd.DataFrame(data0)
    locals()['df{0}'.format(x)] = locals()['df{0}'.format(x)][["prefix","local_label","out_label","next_hop","out_intf","bytes_switched"]]
    locals()['df{0}'.format(x)] = locals()['df{0}'.format(x)].style.set_caption('Host: '+ str(hosts[x+1])).applymap(highlight_cols, subset=pd.IndexSlice[:, ['prefix', 'bytes_switched']])
    display(locals()['df{0}'.format(x)])

print "="*30
print "Configuring SR on PE3 & PE4"
print "="*30

# !ansible-playbook  roles/SR_enable/tasks/SR_enable_XR_routers.yml  --extra-vars "target=PE3,PE4"

print "="*30
print "Prefer SR on PE3 & PE4"
print "="*30

# !ansible-playbook  roles/SR_prefer/tasks/SR-prefer-config.yml  --extra-vars "target=PE3,PE4"

print "="*30
print "Validating configured correctly"
print "="*30

# !ansible-playbook roles/Show_commands/tasks/XR-show-cmd.yml --extra-vars "target=PE3,PE4 commands=['sh running-config router isis xr address-family ipv4 unicast','sh running-config router isis xr interface loopback 0']"


print "="*30
print "Done Move to Next step"
print "="*30
# Out:
# ...
# Pre-check MPLS forwarding before Configuring SR
# ...
#
# PLAY [PE3,PE4] *****************************************************************
#
# TASK [Show command collection for XR] ******************************************
# ok: [PE3]
# ok: [PE4]
#
# TASK [copy] ********************************************************************
# changed: [PE3]
#
# PLAY RECAP *********************************************************************
# PE3                        : ok=2    changed=1    unreachable=0    failed=0
# PE4                        : ok=1    changed=0    unreachable=0    failed=0
# <style  type="text/css" >
#     #T_b69f5226_21c0_11e9_9c9c_000c294bdf13row0_col0 {
#             background-color:  lightyellow;
#         }    #T_b69f5226_21c0_11e9_9c9c_000c294bdf13row0_col5 {
#             background-color:  lightyellow;
#         }    #T_b69f5226_21c0_11e9_9c9c_000c294bdf13row1_col0 {
#             background-color:  lightyellow;
# ...

# %% [markdown]
# #### Validate SR Forwarding on PE3 and PE4

# %%
# !ansible-playbook roles/Show_commands/tasks/ntc-show-cmd.yml --extra-vars "target=PE3,PE4 commands='sh mpls forwarding'"


import ast
import pandas as pd

def highlight_cols(s):
    color = 'lightyellow'
    return 'background-color: %s' % color
hosts = !ansible PE3,PE4 --list-hosts
data = [line.rstrip("\n\r") for line in open("roles/Show_commands/output/show_cmd_ouput_json.txt", "r")]
data = data[0]
data = ast.literal_eval(data)
total_host = len(data)
for x in range(total_host):
    data0 = data[x]
    locals()['df{0}'.format(x)] = pd.DataFrame(data0)
    locals()['df{0}'.format(x)] = locals()['df{0}'.format(x)][["prefix","local_label","out_label","next_hop","out_intf","bytes_switched"]]
    locals()['df{0}'.format(x)] = locals()['df{0}'.format(x)].style.set_caption('Host: '+ str(hosts[x+1])).applymap(highlight_cols, subset=pd.IndexSlice[:, ['prefix', 'bytes_switched']])
    display(locals()['df{0}'.format(x)])


# !ansible-playbook roles/Show_commands/tasks/XR-show-cmd.yml --extra-vars "target=PE3 commands=['sh cef 172.16.0.11/32 detail']"
# !ansible-playbook roles/Show_commands/tasks/XR-show-cmd.yml --extra-vars "target=PE3 commands=['sh cef 172.16.0.22/32 detail']"



print "="*30
print "Done Move to Next step"
print "="*30
# Out:
# PLAY [PE3,PE4] *****************************************************************
#
# TASK [Show command collection for XR] ******************************************
# ok: [PE3]
# ok: [PE4]
#
# TASK [copy] ********************************************************************
# changed: [PE3]
#
# PLAY RECAP *********************************************************************
# PE3                        : ok=2    changed=1    unreachable=0    failed=0
# PE4                        : ok=1    changed=0    unreachable=0    failed=0
# <style  type="text/css" >
#     #T_f3fba548_21c0_11e9_9c9c_000c294bdf13row0_col0 {
#             background-color:  lightyellow;
#         }    #T_f3fba548_21c0_11e9_9c9c_000c294bdf13row0_col5 {
#             background-color:  lightyellow;
#         }    #T_f3fba548_21c0_11e9_9c9c_000c294bdf13row1_col0 {
#             background-color:  lightyellow;
#         }    #T_f3fba548_21c0_11e9_9c9c_000c294bdf13row1_col5 {
# ...

# %% [markdown]
# #### Validate SR Forwarding in Core P1 and P2

# %%
print "="*30
print "clearing MPLS forwarding table"
print "="*30

# !ansible-playbook roles/Show_commands/tasks/XR-show-cmd.yml --extra-vars "target=P1,P2 commands=['clear mpls forwarding counters']"

print "="*30
print "Show MPLS forwarding"
print "="*30


# !ansible-playbook roles/Show_commands/tasks/ntc-show-cmd.yml --extra-vars "target=P1,P2 commands='sh mpls forwarding'"


import ast
import pandas as pd

def highlight_cols(s):
    color = 'lightyellow'
    return 'background-color: %s' % color
hosts = !ansible P1,P2 --list-hosts
data = [line.rstrip("\n\r") for line in open("roles/Show_commands/output/show_cmd_ouput_json.txt", "r")]
data = data[0]
data = ast.literal_eval(data)
total_host = len(data)
for x in range(total_host):
    data0 = data[x]
    locals()['df{0}'.format(x)] = pd.DataFrame(data0)
    locals()['df{0}'.format(x)] = locals()['df{0}'.format(x)][["prefix","local_label","out_label","next_hop","out_intf","bytes_switched"]]
    locals()['df{0}'.format(x)] = locals()['df{0}'.format(x)].style.set_caption('Host: '+ str(hosts[x+1])).applymap(highlight_cols, subset=pd.IndexSlice[:, ['prefix', 'bytes_switched']])
    display(locals()['df{0}'.format(x)])


print "="*30
print "Done Move to Next step"
print "="*30
# Out:
# ...
# clearing MPLS forwarding table
# ...
#
# PLAY [P1,P2] *******************************************************************
#
# TASK [Show command collection for XR] ******************************************
# ok: [P2]
# ok: [P1]
#
# TASK [debug] *******************************************************************
# ok: [P1] => {
#     "show_command.stdout_lines": [
#         [
#             ""
#         ]
#     ]
# }
# ok: [P2] => {
#     "show_command.stdout_lines": [
#         [
#             ""
#         ]
#     ]
# }
#
# PLAY RECAP *********************************************************************
# P1                         : ok=2    changed=0    unreachable=0    failed=0
# P2                         : ok=2    changed=0    unreachable=0    failed=0
#
# ...
# Show MPLS forwarding
# ...
#
# PLAY [P1,P2] *******************************************************************
#
# TASK [Show command collection for XR] ******************************************
# ok: [P2]
# ok: [P1]
#
# ...

# %% [markdown]
# ## ****Now Make PE3 and PE4 as SR only by removing LDP**

# %%
# !ansible-playbook  roles/Remove_LDP/tasks/Remove-LDP-config.yml --extra-vars "target=PE3,PE4"

print "="*30
print "Done Move to Next step"
print "="*30
# Out:
# PLAY [PE3,PE4] *****************************************************************
#
# TASK [Removing MPLS LDP from the Selected XR Routers] **************************
# changed: [PE3]
# changed: [PE4]
#
# PLAY RECAP *********************************************************************
# PE3                        : ok=1    changed=1    unreachable=0    failed=0
# PE4                        : ok=1    changed=1    unreachable=0    failed=0
#
# ...
# Done Move to Next step
# ...

# %% [markdown]
# #### Validate SR Forwarding on PE3 and PE4 Now with LDP removed

# %%
print "="*30
print "sh running-config mpls ldp"
print "="*30

# !ansible-playbook roles/Show_commands/tasks/XR-show-cmd.yml --extra-vars "target=PE3,PE4 commands=['sh running-config mpls ldp']"

print "="*30
print "sh mpls forwarding"
print "="*30

# !ansible-playbook roles/Show_commands/tasks/ntc-show-cmd.yml --extra-vars "target=PE3,PE4 commands='sh mpls forwarding'"


import ast
import pandas as pd

def highlight_cols(s):
    color = 'lightyellow'
    return 'background-color: %s' % color
hosts = !ansible PE3,PE4 --list-hosts
data = [line.rstrip("\n\r") for line in open("roles/Show_commands/output/show_cmd_ouput_json.txt", "r")]
data = data[0]
data = ast.literal_eval(data)
total_host = len(data)
for x in range(total_host):
    data0 = data[x]
    locals()['df{0}'.format(x)] = pd.DataFrame(data0)
    locals()['df{0}'.format(x)] = locals()['df{0}'.format(x)][["prefix","local_label","out_label","next_hop","out_intf","bytes_switched"]]
    locals()['df{0}'.format(x)] = locals()['df{0}'.format(x)].style.set_caption('Host: '+ str(hosts[x+1])).applymap(highlight_cols, subset=pd.IndexSlice[:, ['prefix', 'bytes_switched']])
    display(locals()['df{0}'.format(x)])
    
print "="*30
print "Done Move to Next step"
print "="*30
# Out:
# ...
# sh running-config mpls ldp
# ...
#
# PLAY [PE3,PE4] *****************************************************************
#
# TASK [Show command collection for XR] ******************************************
# ok: [PE3]
# ok: [PE4]
#
# TASK [debug] *******************************************************************
# ok: [PE3] => {
#     "show_command.stdout_lines": [
#         [
#             "% No such configuration item(s)"
#         ]
#     ]
# }
# ok: [PE4] => {
#     "show_command.stdout_lines": [
#         [
#             "% No such configuration item(s)"
#         ]
#     ]
# }
#
# PLAY RECAP *********************************************************************
# PE3                        : ok=2    changed=0    unreachable=0    failed=0
# PE4                        : ok=2    changed=0    unreachable=0    failed=0
#
# ...
# sh mpls forwarding
# ...
#
# PLAY [PE3,PE4] *****************************************************************
#
# ...

# %% [markdown]
# ##  ****Now Configure All GWs as SR**

# %%
# !ansible-playbook  roles/SR_enable/tasks/SR_enable_XR_routers.yml --extra-vars "target=GW"
# !ansible-playbook roles/Show_commands/tasks/XR-show-cmd.yml --extra-vars "target=GW commands=['sh running-config router isis xr address-family ipv4 unicast','sh running-config router isis xr interface loopback 0']"

print "="*30
print "Done Move to Next step"
print "="*30
# Out:
# PLAY [GW] **********************************************************************
#
# TASK [Configuring SR global config selected router] ****************************
# changed: [GW2]
# changed: [GW1]
# changed: [GW4]
# changed: [GW5]
#
# PLAY RECAP *********************************************************************
# GW1                        : ok=1    changed=1    unreachable=0    failed=0
# GW2                        : ok=1    changed=1    unreachable=0    failed=0
# GW4                        : ok=1    changed=1    unreachable=0    failed=0
# GW5                        : ok=1    changed=1    unreachable=0    failed=0
#
#
# PLAY [GW] **********************************************************************
#
# TASK [Show command collection for XR] ******************************************
# ok: [GW1]
# ok: [GW4]
# ok: [GW2]
# ok: [GW5]
#
# TASK [debug] *******************************************************************
# ok: [GW1] => {
#     "show_command.stdout_lines": [
# ...

# %% [markdown]
# #### Validate MPLS Forwarding on GWs

# %%
print "="*30
print "clear mpls forwarding counters"
print "="*30

# !ansible-playbook roles/Show_commands/tasks/XR-show-cmd.yml --extra-vars "target=GW commands=['clear mpls forwarding counters']"

print "="*30
print "sh mpls Forwarding"
print "="*30

# !ansible-playbook roles/Show_commands/tasks/ntc-show-cmd.yml --extra-vars "target=GW commands='sh mpls forwarding'"


import ast
import pandas as pd

def highlight_cols(s):
    color = 'lightyellow'
    return 'background-color: %s' % color
hosts = !ansible GW --list-hosts
data = [line.rstrip("\n\r") for line in open("roles/Show_commands/output/show_cmd_ouput_json.txt", "r")]
data = data[0]
data = ast.literal_eval(data)
total_host = len(data)
for x in range(total_host):
    data0 = data[x]
    locals()['df{0}'.format(x)] = pd.DataFrame(data0)
    locals()['df{0}'.format(x)] = locals()['df{0}'.format(x)][["prefix","local_label","out_label","next_hop","out_intf","bytes_switched"]]
    locals()['df{0}'.format(x)] = locals()['df{0}'.format(x)].style.set_caption('Host: '+ str(hosts[x+1])).applymap(highlight_cols, subset=pd.IndexSlice[:, ['prefix', 'bytes_switched']])
    display(locals()['df{0}'.format(x)])
print "="*30
print "Done Move to Next step"
print "="*30
# Out:
# ...
# clear mpls forwarding counters
# ...
#
# PLAY [GW] **********************************************************************
#
# TASK [Show command collection for XR] ******************************************
# ok: [GW5]
# ok: [GW1]
# ok: [GW2]
# ok: [GW4]
#
# TASK [debug] *******************************************************************
# ok: [GW1] => {
#     "show_command.stdout_lines": [
#         [
#             ""
#         ]
#     ]
# }
# ok: [GW2] => {
#     "show_command.stdout_lines": [
#         [
#             ""
#         ]
#     ]
# }
# ok: [GW4] => {
#     "show_command.stdout_lines": [
#         [
#             ""
#         ]
#     ]
# }
# ok: [GW5] => {
#     "show_command.stdout_lines": [
#         [
#             ""
#         ]
#     ]
# }
#
# PLAY RECAP *********************************************************************
# GW1                        : ok=2    changed=0    unreachable=0    failed=0
# ...

# %% [markdown]
# ## ****Now configure PE1 and PE2 as SR. Also Prefer SR.**

# %%
print "="*30
print "Configuring SR on PE1 & PE2 "
print "="*30

# !ansible-playbook  roles/SR_enable/tasks/SR_enable_XR_routers.yml  --extra-vars "target=PE1,PE2"

print "="*30
print "Prefering SR on PE1 & PE2 "
print "="*30

# !ansible-playbook  roles/SR_prefer/tasks/SR-prefer-config.yml  --extra-vars "target=PE1,PE2"

print "="*30
print "Validating "
print "="*30


# !ansible-playbook roles/Show_commands/tasks/XR-show-cmd.yml --extra-vars "target=PE1,PE2 commands=['sh running-config router isis xr address-family ipv4 unicast','sh running-config router isis xr interface loopback 0']"


print "="*30
print "Done Move to Next step"
print "="*30
# Out:
# ...
# Configuring SR on PE1 & PE2
# ...
#
# PLAY [PE1,PE2] *****************************************************************
#
# TASK [Configuring SR global config selected router] ****************************
# changed: [PE2]
# changed: [PE1]
#
# PLAY RECAP *********************************************************************
# PE1                        : ok=1    changed=1    unreachable=0    failed=0
# PE2                        : ok=1    changed=1    unreachable=0    failed=0
#
# ...
# Prefering SR on PE1 & PE2
# ...
#
# PLAY [PE1,PE2] *****************************************************************
#
# TASK [Configuring SR Prefer on selected Router] ********************************
# changed: [PE1]
# changed: [PE2]
#
# PLAY RECAP *********************************************************************
# PE1                        : ok=1    changed=1    unreachable=0    failed=0
# PE2                        : ok=1    changed=1    unreachable=0    failed=0
#
# ...
# Validating
# ...
#
# ...

# %% [markdown]
# #### Validate SR forwarding on PE1 & PE2

# %%
print "="*30
print "sh mpls Forwarding"
print "="*30

# !ansible-playbook roles/Show_commands/tasks/ntc-show-cmd.yml --extra-vars "target=PE1,PE2 commands='sh mpls forwarding'"


import ast
import pandas as pd

def highlight_cols(s):
    color = 'lightyellow'
    return 'background-color: %s' % color
hosts = !ansible PE1,PE2 --list-hosts
data = [line.rstrip("\n\r") for line in open("roles/Show_commands/output/show_cmd_ouput_json.txt", "r")]
data = data[0]
data = ast.literal_eval(data)
total_host = len(data)
for x in range(total_host):
    data0 = data[x]
    locals()['df{0}'.format(x)] = pd.DataFrame(data0)
    locals()['df{0}'.format(x)] = locals()['df{0}'.format(x)][["prefix","local_label","out_label","next_hop","out_intf","bytes_switched"]]
    locals()['df{0}'.format(x)] = locals()['df{0}'.format(x)].style.set_caption('Host: '+ str(hosts[x+1])).applymap(highlight_cols, subset=pd.IndexSlice[:, ['prefix', 'bytes_switched']])
    display(locals()['df{0}'.format(x)])

# !ansible-playbook roles/Show_commands/tasks/XR-show-cmd.yml --extra-vars "target=PE1,PE2 commands=['sh cef 172.16.0.33/32 detail']"
# !ansible-playbook roles/Show_commands/tasks/XR-show-cmd.yml --extra-vars "target=PE1,PE2 commands=['sh cef 172.16.0.44/32 detail']"


print "="*30
print "Done Move to Next step"
print "="*30
# Out:
# ...
# sh mpls Forwarding
# ...
#
# PLAY [PE1,PE2] *****************************************************************
#
# TASK [Show command collection for XR] ******************************************
# ok: [PE2]
# ok: [PE1]
#
# TASK [copy] ********************************************************************
# changed: [PE1]
#
# PLAY RECAP *********************************************************************
# PE1                        : ok=2    changed=1    unreachable=0    failed=0
# PE2                        : ok=1    changed=0    unreachable=0    failed=0
# <style  type="text/css" >
#     #T_4247dbfc_21c3_11e9_9c9c_000c294bdf13row0_col0 {
#             background-color:  lightyellow;
#         }    #T_4247dbfc_21c3_11e9_9c9c_000c294bdf13row0_col5 {
#             background-color:  lightyellow;
#         }    #T_4247dbfc_21c3_11e9_9c9c_000c294bdf13row1_col0 {
#             background-color:  lightyellow;
#         }    #T_4247dbfc_21c3_11e9_9c9c_000c294bdf13row1_col5 {
# ...

# %% [markdown]
# ## ****Remove MPLS LDP from All routers**

# %%
# !ansible-playbook  roles/Remove_LDP/tasks/Remove-LDP-config.yml --extra-vars "target=PE,core"

print "="*30
print "Done Move to Next step"
print "="*30
# Out:
# PLAY [PE,core] *****************************************************************
#
# TASK [Removing MPLS LDP from the Selected XR Routers] **************************
# changed: [PE3]
# changed: [PE4]
# changed: [PE2]
# changed: [P1]
# changed: [P2]
# changed: [PE1]
# changed: [P3]
# changed: [P4]
#
# PLAY RECAP *********************************************************************
# P1                         : ok=1    changed=1    unreachable=0    failed=0
# P2                         : ok=1    changed=1    unreachable=0    failed=0
# P3                         : ok=1    changed=1    unreachable=0    failed=0
# P4                         : ok=1    changed=1    unreachable=0    failed=0
# PE1                        : ok=1    changed=1    unreachable=0    failed=0
# PE2                        : ok=1    changed=1    unreachable=0    failed=0
# PE3                        : ok=1    changed=1    unreachable=0    failed=0
# ...

# %% [markdown]
# #### Validate MPLS Forwarding on PEs and Core

# %%
print "="*30
print "clear mpls forwarding counters"
print "="*30

# !ansible-playbook roles/Show_commands/tasks/XR-show-cmd.yml --extra-vars "target=PE,core commands=['clear mpls forwarding counters']"

print "="*30
print "sh mpls Forwarding"
print "="*30

# !ansible-playbook roles/Show_commands/tasks/ntc-show-cmd.yml --extra-vars "target=PE,core commands='sh mpls forwarding'"


import ast
import pandas as pd

def highlight_cols(s):
    color = 'lightyellow'
    return 'background-color: %s' % color
hosts = !ansible PE,core --list-hosts
data = [line.rstrip("\n\r") for line in open("roles/Show_commands/output/show_cmd_ouput_json.txt", "r")]
data = data[0]
data = ast.literal_eval(data)
total_host = len(data)
for x in range(total_host):
    data0 = data[x]
    locals()['df{0}'.format(x)] = pd.DataFrame(data0)
    locals()['df{0}'.format(x)] = locals()['df{0}'.format(x)][["prefix","local_label","out_label","next_hop","out_intf","bytes_switched"]]
    locals()['df{0}'.format(x)] = locals()['df{0}'.format(x)].style.set_caption('Host: '+ str(hosts[x+1])).applymap(highlight_cols, subset=pd.IndexSlice[:, ['prefix', 'bytes_switched']])
    display(locals()['df{0}'.format(x)])
    
    

print "="*30
print "Done.Finished with Migration"
print "="*30
# Out:
# ...
# clear mpls forwarding counters
# ...
#
# PLAY [PE,core] *****************************************************************
#
# TASK [Show command collection for XR] ******************************************
# ok: [PE2]
# ok: [PE3]
# ok: [PE1]
# ok: [PE4]
# ok: [P3]
# ok: [P1]
# ok: [P2]
# ok: [P4]
#
# TASK [debug] *******************************************************************
# ok: [PE1] => {
#     "show_command.stdout_lines": [
#         [
#             ""
#         ]
#     ]
# }
# ok: [PE3] => {
#     "show_command.stdout_lines": [
#         [
#             ""
#         ]
#     ]
# }
# ok: [PE2] => {
#     "show_command.stdout_lines": [
#         [
#             ""
#         ]
#     ]
# }
# ok: [PE4] => {
#     "show_command.stdout_lines": [
#         [
#             ""
#         ]
#     ]
# }
# ok: [P1] => {
#     "show_command.stdout_lines": [
#         [
#             ""
#         ]
#     ]
# }
# ok: [P2] => {
#     "show_command.stdout_lines": [
#         [
#             ""
# ...

# %% [markdown]
# ## Thank you.
